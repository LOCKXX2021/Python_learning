# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
lst = []
for i in range(10):
    a = eval(input())
    lst.append(a)
# Out:
# 6.408993680758313
# 6.263545321940282
# 6.191090372462673
# 6.013318551349164
# 5.859692824713596
# 5.432936590831886
# 6.092618484691126
# 6.191090372462673
# 6.329138961975791
# 6.137752031485142

# %%
x_list = np.linspace(0.20,2.00,10)

# %%
plt.plot(x_list,lst)
